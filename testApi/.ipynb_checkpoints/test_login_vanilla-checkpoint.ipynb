# %%
import requests
    
#now we make the test 
login_data = {
        "email": "antoine@zeze.com",
        "password": "toitoit",
      }
r = requests.post("http://localhost:5000/api/v1/login/", json=login_data)
print(r.status_code)
print(r.content)

response_json = r.json()
token = response_json['token']
print(token)


login_data = {
        "email": "antoine@zeze.com",
        "fbToken": "toitoit",
      }
r = requests.post("http://localhost:5000/api/v1/loginFb", json=login_data)
print(r.status_code)
print(r.content)

response_json = r.json()
token = response_json['token']
print(token)


login_data = {
        "email": "antoine@zeze.com",
        "firstName": "toitoit",
        "lastName" : "mointoit",
        "pseudo":"buss",
    "password":"titit"
    
      }
r = requests.post("http://localhost:5000/api/v1/user", json=login_data)
print(r.status_code)
print(r.content)

response_json = r.json()
token = response_json['token']
print(token)


r = requests.get("http://localhost:5000/api/v1/user/111")
print(r.status_code)
print(r.content)

response_json = r.json()
print(response_json)


r = requests.get("http://localhost:5000/api/v1/user/111/stat")
print(r.status_code)
print(r.content)

response_json = r.json()
print(response_json)


r = requests.get("http://localhost:5000/api/v1/user/111/subscriptions")
print(r.status_code)
print(r.content)

response_json = r.json()
print(response_json)



r = requests.get("http://localhost:5000/api/v1/user/111/pictures")
print(r.status_code)
print(r.content)

response_json = r.json()
print(response_json)


login_data = {
        "email": "antoine@zeze.com",
        "firstName": "toitoit",
        "lastName" : "mointoit",
        "pseudo":"buss",
    
      }
r = requests.put("http://localhost:5000/api/v1/user/111", json=login_data)
print(r.status_code)
print(r.content)

response_json = r.json()
token = response_json['ok']
print(token)

login_data = {
        "email": "antoine@zeze.com",
        "firstName": "toitoit",
        "lastName" : "mointoit",
        "pseudo":"buss",
    
      }
r = requests.patch("http://localhost:5000/api/v1/user/111", json=login_data)
print(r.status_code)
print(r.content)

response_json = r.json()
token = response_json['ok']
print(token)
# Out:
# 200
# b'{"token": "AZERTYU3456DFRTY"}'
# AZERTYU3456DFRTY
# 200
# b'{"token": "AZERTYU3456DFRTY"}'
# AZERTYU3456DFRTY
# 200
# b'{"token": "AZERTYU3456DFRTY"}'
# AZERTYU3456DFRTY
# 200
# b'{"pseudo": "pseduo", "firstName": "Dupong", "lastName": "Jean", "email": "JeanDupong@toto.com", "avatar": "http://i.imgur.com/upiU8DO.jpg"}'
# {'pseudo': 'pseduo', 'lastName': 'Jean', 'avatar': 'http://i.imgur.com/upiU8DO.jpg', 'firstName': 'Dupong', 'email': 'JeanDupong@toto.com'}
# 200
# b'{"pictures": 7, "subscriptions": 3, "commissions": 11, "subscribers": 5}'
# {'pictures': 7, 'subscribers': 5, 'commissions': 11, 'subscriptions': 3}
# 200
# b'[{"pseudo": "toto", "id": 3, "avatar": "http://i.imgur.com/upiU8DO.jpg"}, {"pseudo": "titi", "id": 5, "avatar": "http://i.imgur.com/upiU8DO.jpg"}]'
# [{'pseudo': 'toto', 'id': 3, 'avatar': 'http://i.imgur.com/upiU8DO.jpg'}, {'pseudo': 'titi', 'id': 5, 'avatar': 'http://i.imgur.com/upiU8DO.jpg'}]
# 200
# ...
